# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import sklearn as sk
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ibm_attrition_data=pd.read_csv('C:/Users/VICKFURY/Documents/projects/Python Scripts/ml/datasets/ibmattritiondata/IBM Attrition Data.csv')

# %%
ibm_attrition_data.head()
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
# 3   33        No  Research & Development                 3          4
# 4   27        No  Research & Development                 2          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
# 3  Life Sciences                        4                3       Married
# 4        Medical                        1                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# ...

# %%
ibm_attrition_data.tail()
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 1465        Medical                        3                4       Married
# 1466        Medical                        4                1       Married
# 1467  Life Sciences                        2                2       Married
# 1468        Medical                        4                2       Married
# 1469        Medical                        2                3       Married
#
# ...

# %%
ibm_attrition_data.isnull().any()
# Out:
# Age                        False
# Attrition                  False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# EnvironmentSatisfaction    False
# JobSatisfaction            False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked         False
# WorkLifeBalance            False
# YearsAtCompany             False
# dtype: bool

# %%
ibm_attrition_data.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
ibm_attrition_data.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
ibm_attrition_data.Education.unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
ibm_attrition_data.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
ibm_attrition_data.JobSatisfaction.unique()
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
ibm_attrition_data.MaritalStatus.unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
ibm_attrition_data.dtypes
# Out:
# Age                         int64
# Attrition                  object
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EnvironmentSatisfaction     int64
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# NumCompaniesWorked          int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# dtype: object

# %%
class FunEvent:
    def __init__(self,tags,year):
        self.tags=tags
        self.year=year
    def __str__(self):
        return f'FunEvent({self.tags}, year={self.year})'
    
tags=['google','ml']
year=2022
bootcamp=FunEvent(tags,year)
tags.append('bootcamp')
year=2023
print(bootcamp)
# Out:
# FunEvent(['google', 'ml', 'bootcamp'], year=2022)

# %%
ibm_attrition_data.groupby('Attrition').size()
# Out:
# Attrition
# No     1233
# Yes     237
# dtype: int64

# %%
ibm_attrition_data.groupby('EducationField').size()
# Out:
# EducationField
# Human Resources      27
# Life Sciences       606
# Marketing           159
# Medical             464
# Other                82
# Technical Degree    132
# dtype: int64

# %%
plt.figure(figsize=(10,6))
columns=['Human Resources','Life Sciences','Marketing','Medical','Other','Technical Degree']
plt.bar(columns,ibm_attrition_data.groupby('EducationField').size())
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(6,6))
plt.bar(ibm_attrition_data['Age'],ibm_attrition_data['MonthlyIncome'])
plt.xlabel('Age')
plt.ylabel('Monthly Income')
# Out:
# Text(0, 0.5, 'Monthly Income')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
labels=le.fit_transform(ibm_attrition_data.Attrition)

# %%
ibm_attrition_data['labels']=labels

# %%
ibm_attrition_data
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 1      49        No  Research & Development                 8          1
# 2      37       Yes  Research & Development                 2          2
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
labels=[0,1]
plt.figure(figsize=(6,3))
plt.hist(ibm_attrition_data.labels)
plt.xlabel('Attrition')
plt.ylabel('Monthly Income')
# Out:
# Text(0, 0.5, 'Monthly Income')

# %%
plt.figure(figsize=(6,6))
plt.hist(ibm_attrition_data.Age,bins=100)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(6,4))
plt.hist(ibm_attrition_data.MonthlyIncome)
plt.xlabel('Monthly Income')
plt.ylabel('Number of employees')
# Out:
# Text(0, 0.5, 'Number of employees')

# %%
plt.hist(ibm_attrition_data.EnvironmentSatisfaction)
plt.xlabel('EnvironmentSatisfaction')
# Out:
# Text(0.5, 0, 'EnvironmentSatisfaction')

# %%
plt.hist(ibm_attrition_data.YearsAtCompany)
plt.xlabel('Company Time in Years')
# Out:
# Text(0.5, 0, 'Company Time in Years')

# %%
plt.hist(ibm_attrition_data.DistanceFromHome)
plt.xlabel('Home Distance')
# Out:
# Text(0.5, 0, 'Home Distance')

# %%
plt.hist(ibm_attrition_data.)
plt.xlabel('Home Distance')

# %%
plt.hist(ibm_attrition_data.JobSatisfaction)
plt.xlabel('JobSatisfaction')
# Out:
# Text(0.5, 0, 'JobSatisfaction')

# %%
plt.scatter(ibm_attrition_data.JobSatisfaction,ibm_attrition_data.labels)
plt.xlabel('Job Satisfaction')
# Out:
# Text(0.5, 0, 'Job Satisfaction')

# %%
plt.scatter(ibm_attrition_data.JobSatisfaction,ibm_attrition_data.EnvironmentSatisfaction)

# %%
ibm_attrition_data['EducationField'].replace('Life Sciences',1, inplace=True)
ibm_attrition_data['EducationField'].replace('Medical',2, inplace=True)
ibm_attrition_data['EducationField'].replace('Marketing', 3, inplace=True)
ibm_attrition_data['EducationField'].replace('Other',4, inplace=True)
ibm_attrition_data['EducationField'].replace('Technical Degree',5, inplace=True)
ibm_attrition_data['EducationField'].replace('Human Resources', 6, inplace=True)

# %%
ibm_attrition_data['Department'].replace('Research & Development',1, inplace=True)
ibm_attrition_data['Department'].replace('Sales',2, inplace=True)
ibm_attrition_data['Department'].replace('Human Resources', 3, inplace=True)

# %%
ibm_attrition_data['MaritalStatus'].replace('Married',1, inplace=True)
ibm_attrition_data['MaritalStatus'].replace('Single',2, inplace=True)
ibm_attrition_data['MaritalStatus'].replace('Divorced',3, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ibm_attrition_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
features=ibm_attrition_data.columns.drop(['labels','Attrition'])
features
# Out:
# Index(['Age', 'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'NumCompaniesWorked', 'WorkLifeBalance',
#        'YearsAtCompany'],
#       dtype='object')

# %%
for feature in features:
    plt.figure(figsize=(6,6))
    sns.boxplot(x=ibm_attrition_data[feature])
